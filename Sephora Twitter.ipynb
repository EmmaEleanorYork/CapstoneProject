# %%
# !pip install python-twitter
# Out:
# ...
#     100% |████████████████████████████████| 71kB 1.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 829kB 14.4MB/s a 0:00:011
# ...
#     100% |████████████████████████████████| 122kB 31.4MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /Users/emmaeleanoryork/Library/Caches/pip/wheels/bf/c9/a3/c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built future
# ...

# %%
# !pip install tweepy

# %%
from tweepy import Stream

# %%
import tweepy

# creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# setting access token and secret
auth.set_access_token(access_token, access_secret)

# creating the API object while passing in auth information
# the wait on rate avoids asking too much of twitter
api = tweepy.API(auth, 
                 wait_on_rate_limit = True,
                 wait_on_rate_limit_notify = True)

# %%
#You can check how many queries you have left using rate_limit_status() method
api.rate_limit_status()['resources']['search']
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 180, 'reset': 1538764598}}

# %%
# import tweepy
# #override tweepy.StreamListener to add logic to on_status
# class MyStreamListener(tweepy.StreamListener):

#     def on_status(self, status):
#         print(status.text)

# %%
name = "Sephora"
# Number of tweets to pull
tweetCount = 200

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount, include_rts = False)

# %%
# DO NOT RUN THIS CELL AGAIN!!!

sephora_oct_5 = pd.DataFrame(data=[tweet.text for tweet in results],
                             columns = ['Tweets'])

# %%
import pandas as pd

# %%
#RUN ONLY ON END OF DAY OCT 8th

name = "Sephora"
# Number of tweets to pull
tweetCount = 200

# Calling the user_timeline function with our parameters
results = api.user_timeline(id=name, count=tweetCount, include_rts = False)

sephora_oct_8 = pd.DataFrame(data = [tweet.text for tweet in results],
                            columns = ['Tweets'])

# %%
sephora_oct_8.head()
# Out:
#                                               Tweets
# 0  @peungzwb Sorry we're unable to confirm this! ...
# 1  @Seraknits Yes, this is still a benefit for Ro...
# 2  @Seraknits No need to tip for makeover service...
# 3  @breannamlane @megan_snavely Looks like even s...
# 4                                @Mariafbabyy ❤️❤️❤️

# %%
dir(results[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
# ...

# %%
print(results[0].id)
print(results[0].created_at)
print(results[0].source)
print(results[0].favorite_count)
print(results[0].retweet_count)
print(results[0].entities)
# Out:
# 1046879081441058817
# 2018-10-01 21:46:37
# Twitter Web Client
# 1
# 0
# {'hashtags': [{'text': 'SephoraPLAY', 'indices': [108, 120]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ZBAMQueSN1', 'expanded_url': 'https://www.sephora.com/play', 'display_url': 'sephora.com/play', 'indices': [121, 144]}]}

# %%
import numpy as np

# %%
# sephora_oct_1['ID'] = np.array([tweet.id for tweet in results])
# sephora_oct_1['Date'] = np.array([tweet.created_at for tweet in results])
# sephora_oct_1['Source'] = np.array([tweet.source for tweet in results])
# sephora_oct_1['Likes'] = np.array([tweet.favorite_count for tweet in results])
# sephora_oct_1['RTs'] = np.array([tweet.retweet_count for tweet in results])
# sephora_oct_1['Length'] = np.array([len(tweet.text) for tweet in results])

# %%
sephora_oct_8['ID'] = np.array([tweet.id for tweet in results])
sephora_oct_8['Date'] = np.array([tweet.created_at for tweet in results])
sephora_oct_8['Source'] = np.array([tweet.source for tweet in results])
sephora_oct_8['Likes'] = np.array([tweet.favorite_count for tweet in results])
sephora_oct_8['RTs'] = np.array([tweet.retweet_count for tweet in results])
sephora_oct_8['Length'] = np.array([len(tweet.text) for tweet in results])

# %%
sephora_oct_1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bc28d8609e9b> in <module>
# ----> 1 sephora_oct_1.head()
#
# NameError: name 'sephora_oct_1' is not defined

# %%
sephora_oct_8.head()
# Out:
#                                               Tweets                   ID  \
# 0  @peungzwb Sorry we're unable to confirm this! ...  1048276426850324480
# 1  @Seraknits Yes, this is still a benefit for Ro...  1048275945411424256
# 2  @Seraknits No need to tip for makeover service...  1048272782902013952
# 3  @breannamlane @megan_snavely Looks like even s...  1048268163824017409
# 4                                @Mariafbabyy ❤️❤️❤️  1048267553716326400
#
#                  Date              Source  Likes  RTs  Length
# 0 2018-10-05 18:19:10       Lithium Tech.      0    0     102
# 1 2018-10-05 18:17:16       Lithium Tech.      1    0     140
# 2 2018-10-05 18:04:42       Lithium Tech.      0    0      62
# 3 2018-10-05 17:46:20  Twitter Web Client      0    0      70
# 4 2018-10-05 17:43:55  Twitter Web Client      0    0      19

# %%
sephora_oct_1.set_index('Date', inplace=True)

# %%
sephora_oct_1.head()
# Out:
#                                                                 Tweets  \
# Date
# 2018-10-01 21:46:37  From farm to vanity 🍊 Get seven samples featur...
# 2018-10-01 21:43:45  @jillianro20 If you need assistance with an or...
# 2018-10-01 21:43:29  @chew_beccaa We're so sorry to hear that! We k...
# 2018-10-01 21:40:37  @FaceOfMS We're very sorry about that! We are ...
# 2018-10-01 21:05:37  @tristaawtrey Oh no! Please send a DM with you...
#
#                                       ID              Source  Likes  RTs  \
# Date
# 2018-10-01 21:46:37  1046879081441058817  Twitter Web Client      1    0
# 2018-10-01 21:43:45  1046878359383207936       Lithium Tech.      0    0
# 2018-10-01 21:43:29  1046878291687178240       Lithium Tech.      0    0
# 2018-10-01 21:40:37  1046877569851613184       Lithium Tech.      0    0
# 2018-10-01 21:05:37  1046868763272929281       Lithium Tech.      0    0
#
#                      Length
# Date
# 2018-10-01 21:46:37     144
# ...

# %%
sephora_oct_5.set_index('Date', inplace=True)

# %%
sephora_oct_5.to_csv('sephora_oct_5-.csv')

# %%
sephora_oct_8.set_index('Date', inplace=True)

# %%
sephora_oct_8.to_csv('sephora_oct_8-.csv')

# %%
len(sephora_oct_1)
# Out:
# 200

# %%
len(sephora_oct_5)
# Out:
# 200

# %%
len(sephora_oct_1[sephora_oct_1['Tweets'].str.contains('new')])
# Out:
# 5

# %%
len(sephora_oct_5[sephora_oct_5['Tweets'].str.contains('new')])
# Out:
# 4

# %%
sephora_oct_1[sephora_oct_1['Tweets'].str.contains('new')]
# Out:
#                                                                 Tweets  \
# Date
# 2018-10-01 21:43:29  @chew_beccaa We're so sorry to hear that! We k...
# 2018-10-01 18:49:03  @Laiksee Thank you for your interest in Sephor...
# 2018-09-30 16:39:05  @Feelinirih2 Sorry about this experience! The ...
# 2018-09-30 16:18:17  @HungerHuman The new shades should be availabl...
# 2018-09-28 15:41:49  The glow is real ✨ Get a real-life beauty filt...
#
#                                       ID              Source  Likes  RTs  \
# Date
# 2018-10-01 21:43:29  1046878291687178240       Lithium Tech.      0    0
# 2018-10-01 18:49:03  1046834394957152256       Lithium Tech.      1    0
# 2018-09-30 16:39:05  1046439300361928704       Lithium Tech.      0    0
# 2018-09-30 16:18:17  1046434065581129728       Lithium Tech.      1    0
# 2018-09-28 15:41:49  1045700112717045761  Twitter Web Client    112   17
#
#                      Length
# Date
# 2018-10-01 21:43:29     140
# ...

# %%
sephora_oct_1.tail()
# Out:
#                                                                 Tweets  \
# Date
# 2018-09-26 21:58:09  @thecatsmeow0410 We're so sorry to hear about ...
# 2018-09-26 21:47:28  @DaddyBlaytz Hi there, we're so sorry to hear ...
# 2018-09-26 21:40:52  @_lmzp Hi there! For assistance with Sephora U...
# 2018-09-26 21:30:15  @SeattleRJH We're sorry to hear this! Please s...
# 2018-09-26 21:28:58  @geminicole Hi there, we appreciate your feedb...
#
#                                       ID         Source  Likes  RTs  Length
# Date
# 2018-09-26 21:58:09  1045070044726587392  Lithium Tech.      0    0     140
# 2018-09-26 21:47:28  1045067356496584706  Lithium Tech.      0    0     140
# 2018-09-26 21:40:52  1045065693723578369  Lithium Tech.      2    1     140
# 2018-09-26 21:30:15  1045063023986008064  Lithium Tech.      0    0     140
# 2018-09-26 21:28:58  1045062699678220288  Lithium Tech.      0    0     140

# %%
sephora_oct_1.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3fa59a8153e7> in <module>
# ----> 1 sephora_oct_1.tail()
#
# NameError: name 'sephora_oct_1' is not defined

# %%
sephora_oct_5.tail()
# Out:
#                                                                 Tweets  \
# Date
# 2018-10-02 01:41:51  @TheMegnar Hi there, we invite you to share yo...
# 2018-10-02 00:51:01  @illybels Sorry to hear that! If you need assi...
# 2018-10-01 23:59:40  @_lindaaaxo Hi there! Please send us a DM with...
# 2018-10-01 23:42:33  @CyndyPan We're sorry that your package arrive...
# 2018-10-01 23:28:05  @alexiacapitina We're sorry to hear that! Plea...
#
#                                       ID         Source  Likes  RTs  Length
# Date
# 2018-10-02 01:41:51  1046938278258126848  Lithium Tech.      0    0      83
# 2018-10-02 00:51:01  1046925486595563520  Lithium Tech.      0    0     138
# 2018-10-01 23:59:40  1046912564293132288  Lithium Tech.      1    0     118
# 2018-10-01 23:42:33  1046908254427598848  Lithium Tech.      0    0     118
# 2018-10-01 23:28:05  1046904614363181056  Lithium Tech.      0    0     110

# %%
sephora_oct_1.sort_index(ascending = True)
# Out:
#                                                                 Tweets  \
# Date
# 2018-09-26 21:28:58  @geminicole Hi there, we appreciate your feedb...
# 2018-09-26 21:30:15  @SeattleRJH We're sorry to hear this! Please s...
# 2018-09-26 21:40:52  @_lmzp Hi there! For assistance with Sephora U...
# 2018-09-26 21:47:28  @DaddyBlaytz Hi there, we're so sorry to hear ...
# 2018-09-26 21:58:09  @thecatsmeow0410 We're so sorry to hear about ...
# 2018-09-26 22:23:14  @smileitismorgan We're very sorry about that! ...
# 2018-09-26 22:25:02  @LibrarianE13 We feel it's a personal choice. ...
# 2018-09-26 22:57:01  @water_bleu No lie, those socks look so cozy a...
# 2018-09-26 22:57:12                                        @melbot5 ❤️
# 2018-09-26 22:57:33  @arceo19_ @ABHcosmetics @Maybelline @MorpheBru...
# 2018-09-26 23:09:11  @RiaIzaRHO @patmcgrathreal Such a good choice!...
# 2018-09-26 23:10:05  @HannahPWall @fentybeauty @rihanna @HarveyNich...
# ...

# %%
# def get_tweets(username): 
          
#         # Authorization to consumer key and consumer secret 
#         auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
#         # Access to user's access key and access secret 
#         auth.set_access_token(access_token, access_secret) 
  
#         # Calling api 
#         api = tweepy.API(auth) 
  
#         # 200 tweets to be extracted 
#         number_of_tweets=200
#         tweets = api.user_timeline(screen_name=username) 
  
#         # Empty Array 
#         tmp=[]  
  
#         # create array of tweet information: username,  
#         # tweet id, date/time, text 
#         tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
#         for j in tweets_for_csv: 
  
#             # Appending tweets to the empty array tmp 
#             tmp.append(j)  
  
#         # Printing the tweets 
#         print(tmp)

# %%
#get_tweets('Sephora')
